# %% [markdown]
# <a href="https://colab.research.google.com/github/MorningStarTM/fighter-jet-detection-using-yolov8/blob/main/Jet_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.7 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Project_Jet
# Out:
# /content/drive/MyDrive/Project_Jet

# %%
# %ls Data/train/
# Out:
# images/  labels/  labels.cache

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= config.yaml epochs=60 imgsz=256 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img_path = "/content/drive/MyDrive/Project_Jet/Data/train/images/02530f4f-frame_6770.jpg"
img = cv2.imread(img_path)
plt.imshow(img)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Project_Jet/runs/detect/train4/weights/best.pt conf=0.25 source="/content/drive/MyDrive/Project_Jet/Data/train/images/02530f4f-frame_6770.jpg" save=True
# Out:
# 2023-08-07 12:28:57.036149: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 12:28:59.541234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/Project_Jet/Data/train/images/02530f4f-frame_6770.jpg: 160x256 1 Fighter_Jet, 69.1ms
# Speed: 0.5ms pre-process, 69.1ms inference, 6.1ms postprocess per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/predict2
